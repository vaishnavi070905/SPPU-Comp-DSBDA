# %%
import pandas as pd

# %%
df = pd.read_csv("emp_information.csv")

# %%
print(df)
# Out:
#     Employee ID First Name Last Name  Gender Department              Position  \
# 0          1001      Vikas   Agarwal  Female  Marketing        SEO Specialist
# 1          1002       Neha     Verma  Female  Marketing     Marketing Analyst
# 2          1003      Rohit     Patel    Male         IT    Software Developer
# 3          1004       Amit       Das    Male         HR             Recruiter
# 4          1005      Nisha     Gupta    Male         IT  System Administrator
# ..          ...        ...       ...     ...        ...                   ...
# 70         1071      Sneha   Agarwal  Female    Finance            Accountant
# 71         1072      Priya       Das    Male         HR             Recruiter
# 72         1073      Rohit     Yadav  Female    Support      Support Engineer
# 73         1074       Amit      Jain  Female    Finance     Financial Analyst
# 74         1075      Sneha     Joshi  Female         HR          HR Executive
#
# ...

# %%
# Display first few rows
print(df.head())
# Out:
#    Employee ID First Name Last Name  Gender Department              Position  \
# 0         1001      Vikas   Agarwal  Female  Marketing        SEO Specialist
# 1         1002       Neha     Verma  Female  Marketing     Marketing Analyst
# 2         1003      Rohit     Patel    Male         IT    Software Developer
# 3         1004       Amit       Das    Male         HR             Recruiter
# 4         1005      Nisha     Gupta    Male         IT  System Administrator
#
#    Salary                     Email       City        State  Unnamed: 10  \
# 0  743292  vikas.agarwal0@email.com    Chennai   Tamil Nadu          NaN
# 1  689981     neha.verma1@email.com       Pune  Maharashtra          NaN
# 2  567496    rohit.patel2@email.com  Bangalore    Karnataka          NaN
# 3  536899       amit.das3@email.com  Hyderabad    Telangana          NaN
# 4  715067    nisha.gupta4@email.com     Mumbai  Maharashtra          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# ...

# %%
# Check dimensions
print("Shape:", df.shape)
# Out:
# Shape: (75, 15)

# %%
# Check data types
print("\nData Types:\n", df.dtypes)

# %%
# Check missing values
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Employee ID     0
# First Name      0
# Last Name       0
# Gender          0
# Department      0
# Position        0
# Salary          0
# Email           0
# City            0
# State           0
# Unnamed: 10    75
# Unnamed: 11    75
# Unnamed: 12    75
# Unnamed: 13    75
# Unnamed: 14    75
# dtype: int64

# %%
# Describe data
print("\nStatistics:\n", df.describe())
# Out:
# Statistics:
#         Employee ID         Salary  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# count    75.000000      75.000000          0.0          0.0          0.0
# mean   1038.000000  565276.386667          NaN          NaN          NaN
# std      21.794495  139489.928890          NaN          NaN          NaN
# min    1001.000000  302713.000000          NaN          NaN          NaN
# 25%    1019.500000  436918.500000          NaN          NaN          NaN
# 50%    1038.000000  567496.000000          NaN          NaN          NaN
# 75%    1056.500000  671677.000000          NaN          NaN          NaN
# max    1075.000000  798225.000000          NaN          NaN          NaN
#
#        Unnamed: 13  Unnamed: 14
# count          0.0          0.0
# mean           NaN          NaN
# std            NaN          NaN
# min            NaN          NaN
# 25%            NaN          NaN
# 50%            NaN          NaN
# 75%            NaN          NaN
# ...

# %%
# Convert categorical to numeric (example)
df = pd.get_dummies(df, drop_first=True)

# %%
print("\nAfter Encoding:\n", df.head())
# Out:
# After Encoding:
#     Employee ID  Salary  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         1001  743292          NaN          NaN          NaN          NaN
# 1         1002  689981          NaN          NaN          NaN          NaN
# 2         1003  567496          NaN          NaN          NaN          NaN
# 3         1004  536899          NaN          NaN          NaN          NaN
# 4         1005  715067          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  First Name_Anjali  First Name_Arjun  First Name_Deepak  ...  \
# 0          NaN              False             False              False  ...
# 1          NaN              False             False              False  ...
# 2          NaN              False             False              False  ...
# 3          NaN              False             False              False  ...
# 4          NaN              False             False              False  ...
#
# ...

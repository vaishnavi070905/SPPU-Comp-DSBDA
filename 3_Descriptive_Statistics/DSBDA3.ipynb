# %% [markdown]
# Perform the following operations on any open-source dataset (e.g., dataset related to age, income, etc.):
#
# 1. Provide summary statistics (mean, median, minimum, maximum, standard deviation, etc.) for a dataset with numeric variables grouped by a categorical variable.
# Example: If your categorical variable is age group and your quantitative variable is income, then provide summary statistics of income for the age groups.
# Create a list that contains a numeric value and a categorical variable.
#
# 2. Write a Python program to display some basic statistical details such as mean, median, mode, standard deviation, etc., of the species ‘Iris-setosa’, ‘Iris-versicolor’, and ‘Iris-virginica’ of the iris.csv dataset.
#
# Provide the codes with outputs and explain everything that you do in the report.

# %%
import pandas as pd

# %%
df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df["SepalLengthCm"].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: SepalLengthCm, dtype: float64

# %%
df.groupby('Species').describe()
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
df.groupby('Species').describe().sum()
# Out:
# Id             count    150.000000
#                mean     226.500000
#                std       43.732139
#                min      153.000000
#                25%      189.750000
#                50%      226.500000
#                75%      263.250000
#                max      300.000000
# SepalLengthCm  count    150.000000
#                mean      17.530000
#                std        1.504540
#                min       14.100000
#                25%       16.625000
#                50%       17.400000
#                75%       18.400000
#                max       20.700000
# SepalWidthCm   count    150.000000
#                mean       9.162000
#                std        1.017319
#                min        6.500000
#                25%        8.450000
#                50%        9.200000
#                75%        9.850000
#                max       11.600000
# PetalLengthCm  count    150.000000
#                mean      11.276000
#                std        1.195317
# ...
